# %% [markdown]
# # Ebay Germany Car Sale Data Exploration

# %% [markdown]
# This projects guide you through the cleaning and analysis of the [ebay car sale dataset.](https://www.kaggle.com/orgesleka/used-cars-database) We will use python based data analysis library: Pandas, Numpy, and seaborn to perform the exploratory data analysis of this dataset.

# %%
# Importing the required library
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Lets load the dataset and have a glimpse on it.

# %%
data_file = "autos.csv"
# Since pandas default accepted encoding of csv is UTF-8, \
# we need to specify the encoding if it differs.
autos_data = pd.read_csv(data_file,encoding="Latin-1") 
print(autos_data.info())
autos_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos_data.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos_data.rename(columns = {'offerType':'offer_type','price':'price_$','abtest':'ab_test','vehicletype':'vehicle_type', \
                             'yearOfRegistration':'year_of_registration','gearbox':'gear_box','powerPS':'power_ps', \
                             'odometer':'odometer_km','monthOfRegistration':'month_of_registration','fuelType':'fuel_type', \
                             'notRepairedDamage':'not_repaired_damage','dateCreated':'ad_created', \
                             'nrOfPictures':'nr_of_pictures','postalCode':'postal_code','lastSeen':'last_seen'},inplace=True)
autos_data.head(3)
# Out:
#            dateCrawled                                        name  seller  \
# 0  2016-03-26 17:47:46            Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1  2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
# 2  2016-03-26 18:57:24                  Volkswagen_Golf_1.6_United  privat
#
#   offer_type price_$  ab_test vehicleType  year_of_registration   gear_box  \
# 0    Angebot  $5,000  control         bus                  2004    manuell
# 1    Angebot  $8,500  control   limousine                  1997  automatik
# 2    Angebot  $8,990     test   limousine                  2009    manuell
#
#    power_ps   model odometer_km  month_of_registration fuel_type       brand  \
# 0       158  andere   150,000km                      3       lpg     peugeot
# 1       286     7er   150,000km                      6    benzin         bmw
# 2       102    golf    70,000km                      7    benzin  volkswagen
#
# ...

# %%
autos_data.describe(include='all')
# Out:
#                 dateCrawled         name  seller offer_type price_$ ab_test  \
# count                 50000        50000   50000      50000   50000   50000
# unique                48213        38754       2          2    2357       2
# top     2016-03-22 09:51:06  Ford_Fiesta  privat    Angebot      $0    test
# freq                      3           78   49999      49999    1421   25756
# mean                    NaN          NaN     NaN        NaN     NaN     NaN
# std                     NaN          NaN     NaN        NaN     NaN     NaN
# min                     NaN          NaN     NaN        NaN     NaN     NaN
# 25%                     NaN          NaN     NaN        NaN     NaN     NaN
# 50%                     NaN          NaN     NaN        NaN     NaN     NaN
# 75%                     NaN          NaN     NaN        NaN     NaN     NaN
# max                     NaN          NaN     NaN        NaN     NaN     NaN
#
# ...

# %% [markdown]
# From the summary above, we can see that offer_type and seller columns same data repetition and hence does not help in analysing the dataset.  So, we can delete this two columns. In addition,we noticed many non-text datatype stored as text and hence need data-type conversion to its correct format.

# %%
autos_data.drop(["seller", "offer_type"], axis=1, inplace=True)
autos_data.shape
# Out:
# (50000, 18)

# %% [markdown]
# we will now update the price and odometer column to make the data numeric and analysable.

# %%
autos_data['price_$'] = autos_data['price_$'].str.replace('$','')
autos_data['price_$'] = autos_data['price_$'].str.replace(',','')
autos_data['price_$'] = autos_data['price_$'].astype(float)
autos_data['price_$'].dtype
# Out:
# dtype('float64')

# %%
autos_data['odometer_km'] = autos_data['odometer_km'].str.strip('km')
autos_data['odometer_km'] = autos_data['odometer_km'].str.replace(',','')
autos_data['odometer_km'] = autos_data['odometer_km'].astype(int)
autos_data['odometer_km'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Upon close observation, we can see the price range is very high (0.0 - 99999999.0).  Since, the  few max price are  unique and quite high compared to other prices.The prices of car in million available in ebay website is quite rare and hence we can consider the price above half million  as an outlier and thus remove them. Also the least price (0.0) is removed as an outlier.

# %%
 autos_data= autos_data.loc[(autos_data['price_$'] > 0.0) & (autos_data['price_$'] < 500000 )]

# %%
print(max(autos_data['price_$']))
print(min(autos_data['price_$']))
# Out:
# 350000.0
# 1.0

# %% [markdown]
# Now, lets check the data type of the columns that has date in it and convert it to datetime format

# %%
autos_data.columns
# Out:
# Index(['dateCrawled', 'name', 'price_$', 'ab_test', 'vehicleType',
#        'year_of_registration', 'gear_box', 'power_ps', 'model', 'odometer_km',
#        'month_of_registration', 'fuel_type', 'brand', 'not_repaired_damage',
#        'ad_created', 'nr_of_pictures', 'postal_code', 'last_seen'],
#       dtype='object')

# %%
autos_data[['dateCrawled', 'year_of_registration','month_of_registration', 'ad_created','last_seen']].dtypes
# Out:
# dateCrawled              object
# year_of_registration      int64
# month_of_registration     int64
# ad_created               object
# last_seen                object
# dtype: object

# %%
autos_data[['dateCrawled', 'year_of_registration','month_of_registration', 'ad_created','last_seen']].head()
# Out:
#            dateCrawled  year_of_registration  month_of_registration  \
# 0  2016-03-26 17:47:46                  2004                      3
# 1  2016-04-04 13:38:56                  1997                      6
# 2  2016-03-26 18:57:24                  2009                      7
# 3  2016-03-12 16:58:10                  2007                      6
# 4  2016-04-01 14:38:50                  2003                      7
#
#             ad_created            last_seen
# 0  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 00:00:00  2016-04-01 14:38:50

# %% [markdown]
# Lets observe now each column closely and see the data distribution. From above we saw dates are in string format, so we convert it to numeric format. Since, we are more concerned on date rather than time , we only considered the count in each day.

# %%
crawled_date = autos_data['dateCrawled'].str[:10].value_counts(normalize=True,dropna=False).sort_index()
crawled_date
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: dateCrawled, dtype: float64

# %%
plt.scatter(range(len(crawled_date.index)), crawled_date)
plt.ylim()
# Out:
# (-0.02, 0.06)

# %% [markdown]
# From the abover data, we can see that data from ebay were crawled everyday for the span of about a month. The crawling was done uniformly each day, with few exceptionds(detail can be seen in figure above).

# %%
ad_created_date = autos_data['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
ad_created_date
# Out:
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
# 2015-12-30    0.000021
# 2016-01-03    0.000021
# 2016-01-07    0.000021
# 2016-01-10    0.000041
# 2016-01-13    0.000021
# 2016-01-14    0.000021
# 2016-01-16    0.000021
# 2016-01-22    0.000021
# 2016-01-27    0.000062
# 2016-01-29    0.000021
# 2016-02-01    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000021
# 2016-02-08    0.000021
# 2016-02-09    0.000021
# 2016-02-11    0.000021
# 2016-02-12    0.000041
# 2016-02-14    0.000041
# 2016-02-16    0.000021
# 2016-02-17    0.000021
# 2016-02-18    0.000041
# 2016-02-19    0.000062
# 2016-02-20    0.000041
# 2016-02-21    0.000062
#                 ...
# 2016-03-09    0.033151
# 2016-03-10    0.031895
# 2016-03-11    0.032904
# 2016-03-12    0.036755
# 2016-03-13    0.017008
# 2016-03-14    0.035190
# 2016-03-15    0.034016
# 2016-03-16    0.030125
# 2016-03-17    0.031278
# ...

# %%
plt.scatter(range(len(ad_created_date)), ad_created_date)

# %% [markdown]
# From the data as well as the plot it can be seen that creation of advertisement was relatively low initially (year 2015). The ad creation peak from the march of 2016 and seems to remain uniform. Also, another point to note is the relation between the date when ad was created asnd crawled.

# %%
date_last_seen = autos_data['last_seen'].str[:10].value_counts(normalize=True).sort_index()
date_last_seen
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %%
plt.scatter(range(len(date_last_seen)), date_last_seen)

# %% [markdown]
# The last observation also seems to be quite uniform. It can be assumed that last seen date might the date cars were sold. From it, we can colclude that data might contain some error value or few last days might be the extreme sales days.
#
#
# Now, Lets watch the dates that are already in numerical format using the pandas describe methods.

# %%
autos_data['year_of_registration'].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: year_of_registration, dtype: float64

# %% [markdown]
# From ther description of the data , we can clearly seem some values that are not relevant.Minimum year is 1000, which is far earlier that cars era whereas maximum year is also 9999(unknown future).The mean year and median year both are 2004. The majority of car were in range of 1999-2008. More than 1-4th pf cars in ebay were manufactured before year 2000 and only about a fifth of cars were built in year 2010 or later.

# %%
autos_data['month_of_registration'].describe()
# Out:
# count    48565.000000
# mean         5.782251
# std          3.685595
# min          0.000000
# 25%          3.000000
# 50%          6.000000
# 75%          9.000000
# max         12.000000
# Name: month_of_registration, dtype: float64

# %% [markdown]
# The date shows the uniform distribution of registration of cars sale throughout the year as car registration is about 25% in each quarter.

# %% [markdown]
# Since , we observed some incorrect values in 'year_of_registration' column, we will update those incorrect values. We will check the data and consider them outlier if they are before 1900 and after the current date. If these valuers are less than 5% (threshold value, we will considering removing the entire rows containing such value rather than performing other data imputing operations.

# %%
1 - ((autos_data['year_of_registration'].between(1900,2016)).sum()/autos_data.shape[0])
# Out:
# 0.03879336971069702

# %% [markdown]
# There is only about 3.9% of data that seems to be outlier, which is less than our threshold value. Hence we can remove the rows that contains these values.

# %%
autos_data.shape
# Out:
# (48565, 18)

# %%
autos_data = autos_data[autos_data['year_of_registration'].between(1900,2016)]
autos_data.shape
# Out:
# (46681, 18)

# %%
year_registration = autos_data['year_of_registration'].value_counts(normalize=True).sort_index()
year_registration.head()
# Out:
# 1910    0.000107
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000043
# Name: year_of_registration, dtype: float64

# %%
plt.scatter(range(len(year_registration)), year_registration)

# %% [markdown]
# The plot shows that registration of cars were mostly done in last 20 years . The majority of car were registered in year 2026(almost 7%).

# %%
print("{}:{:.2f}%".format(max(year_registration.index), (max(year_registration)*100)))
# Out:
# 2016:6.76%

# %%
print(autos_data['brand'].unique().shape)
# Out:
# (40,)

# %% [markdown]
# Now, we will explore the various brands of cars.We find out there are fourty different brands of cars in our dataset. Lets check the dataset.

# %%
brands_cars = autos_data['brand'].value_counts(normalize=True)
popular_brands = brands_cars[brands_cars > 0.10].index
popular_brands
# Out:
# Index(['volkswagen', 'bmw', 'opel'], dtype='object')

# %% [markdown]
# There are only three brands that have more than 10% cars of it in this rbay car sales data. All of them are German based, of which, Volswagen is the frontrunner with more than a-fifth of the ebay car sales market.

# %%
cars_collection = {}

for brand in autos_data['brand']:
    if brand not in  cars_collection:
        cars_collection[brand] = 1
    else:
        cars_collection[brand] += 1
mean_value_cars_brands = pd.Series ([cars_collection[k] for k in cars_collection]).mean()

# %%
popular_brands_price = {}

for  brand in popular_brands:
    brand_ = autos_data[autos_data['brand'] == brand]
    price = brand_['price_$'].mean()
    popular_brands_price[brand] = int(price)
popular_brands_price
# Out:
# {'bmw': 8332, 'opel': 2975, 'volkswagen': 5402}

# %%
mean_prices_brand = autos_data.groupby('brand')['price_$'].mean()
mean_prices_brand = mean_prices_brand.astype(int)

# %% [markdown]
# We aggregate our popular car brands with their price value and get the mean price of easch brands. From the aggregation, we get that Opel cars seems to be quite cheaply available  as its mean price is less than 3000 whereas BMW is quite high and data reveals the brand value upon the mean price.

# %%
df = pd.DataFrame(mean_prices_brand)
df.head()
# Out:
#             price_$
# brand
# alfa_romeo     4087
# audi           9336
# bmw            8332
# chevrolet      6684
# chrysler       3465

# %%
del df.index.name
df.head()
# Out:
#             price_$
# alfa_romeo     4087
# audi           9336
# bmw            8332
# chevrolet      6684
# chrysler       3465

# %%
brands_mean_price = {}
brands_mean_mileage = {}

for brand in brands_cars.index:
    brand_ = autos_data[autos_data['brand'] == brand]
    price = brand_['price_$'].mean()
    mileage = brand_['odometer_km'].mean()
    brands_mean_price[brand] = int(price)
    brands_mean_mileage[brand] = int(mileage)

# %%
brands_mean_price = pd.Series(brands_mean_price)
brands_df = pd.DataFrame(brands_mean_price, columns=['mean_price'])
brands_mean_mileage = pd.Series(brands_mean_mileage)
brands_df['mean_mileage'] = brands_mean_mileage
brands_df.head()
# Out:
#             mean_price  mean_mileage
# alfa_romeo        4087        131338
# audi              9336        129157
# bmw               8332        132572
# chevrolet         6684         99191
# chrysler          3465        132378

# %%
print(brands_df.corr())
print(brands_df.describe())
# Out:
#               mean_price  mean_mileage
# mean_price      1.000000     -0.184035
# mean_mileage   -0.184035      1.000000
#          mean_price   mean_mileage
# count     40.000000      40.000000
# mean    6432.050000  116697.900000
# std     7313.465322   17986.516703
# min     1049.000000   54538.000000
# 25%     3334.750000  110252.250000
# 50%     4109.500000  121771.000000
# 75%     6447.000000  128230.000000
# max    45643.000000  144415.000000

# %% [markdown]
# The correlation between the price tends to be negative  and very low.The average price of the various brands ranges from 1049 to  to 45643 Euros whereas the overall mean price tends be about 6400 contrary to median value(~4100e). This shows the skewness in price distribution.  The mileage distribution seems to be more normal compared to price.
