# %% [markdown]
# # Visualizing the College Majors based Earnings

# %% [markdown]
# In this project, we will analyse the job outcomes of the graduate from differnt majors in between 2010 and 2012. The raw data was collected by [American Community Survey](https://www.census.gov/programs-surveys/acs/),which was further cleaned and provided by [FiveThirtyEight](https://github.com/fivethirtyeight/data/tree/master/college-majors).
#
# We will mainly focus on data visualization and try to answer various questions bsased on the plots we create. let start the project by import all the required python libraries.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
file = 'recent-grads.csv'
recent_grads = pd.read_csv(file)

# %%
recent_grads.iloc[0,:]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.isnull().sum()
# Out:
# Rank                    0
# Major_code              0
# Major                   0
# Total                   1
# Men                     1
# Women                   1
# Major_category          0
# ShareWomen              1
# Sample_size             0
# Employed                0
# Full_time               0
# Part_time               0
# Full_time_year_round    0
# Unemployed              0
# Unemployment_rate       0
# Median                  0
# P25th                   0
# P75th                   0
# College_jobs            0
# Non_college_jobs        0
# Low_wage_jobs           0
# dtype: int64

# %% [markdown]
# From above , we can see that  few columns have null values and can be omitted.

# %%
raw_data_count = recent_grads.shape[0]

# %%
recent_grads.dropna(how='any',axis=0, inplace=True)

# %%
recent_grads.shape
# Out:
# (172, 21)

# %%
cleaned_data_count = recent_grads.shape[0]

# %%
cleaned_data_count == raw_data_count
# Out:
# False

# %% [markdown]
# The above code verifies that missing values have been dropped. Now, lets visualize our data using the pandas plot method to understand the data further.

# %%
recent_grads.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
recent_grads.plot(x='Sample_size', y='Median',kind='scatter',title='Sample Size vs Median')

# %% [markdown]
# The plot shows that there is no clear correlation between the sample size(majors populasrity) and median  income.

# %%
recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter',title='Sample Size vs Unemployment Rate')

# %%
recent_grads.plot(x='Full_time',y='Median',kind='scatter',title='Full time vs Median')

# %% [markdown]
# There is almost no correlation between full time employees and their median salary.

# %%
recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter',title='ShareWomen vs Unemployment Rate')

# %%
recent_grads.plot(x='Men',y='Median',kind='scatter',title='Men vs Women')

# %%
recent_grads.plot(x='Women',y='Median',kind='scatter',title='Women vs Women')

# %%
recent_grads['Sample_size'].plot(kind='hist')

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,4500))

# %%
recent_grads['Median'].plot(kind='hist',bins=25)

# %% [markdown]
# This histogram demonstrates the median salary of gradute from various majors. From this histogram, we can conclude that 35000 is the most common median salary as its frquency is quite high(nearly 50) compared to other. we can verify this numerically by the following code.The code shows about 56% major are female predominant.

# %%
(len(recent_grads['ShareWomen'][recent_grads['ShareWomen'] > 0.50]))/(len(recent_grads['ShareWomen']))
# Out:
# 0.5581395348837209

# %%
recent_grads['Employed'].plot(kind='hist',bins=25)

# %%
recent_grads['Full_time'].plot(kind='hist',bins=25)

# %%
recent_grads['ShareWomen'].plot(kind='hist',bins=10)

# %% [markdown]
# Looking at this histogram, we can see that frequency of predominantly Sharewomen (i.e.> 0.5) is roughly half and thus we can conclude that about 50% of the majors were predominantly female and similar to that predominantly male.

# %%
recent_grads['Unemployment_rate'].plot(kind='hist',bins=20)

# %%
recent_grads['Men'].plot(kind='hist',bins=50)

# %%
recent_grads['Women'].plot(kind='hist',bins=50)

# %% [markdown]
# We can combine the scatter plot and histogram togeher and plot the correlation as well as individual features in the same plot using the panda's scatter_matrix plot method. First we will see the correlation between "sample size" and "Median" as well as their individual histogram by forming 2`*`2 scatter matrix, followed by 3`*`3 matrix of "sample size", "Median", and "Unemployment rate".

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a4c85a7f0>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5a4c5702e8>,
# ...
#       dtype=object)

# %% [markdown]
# Now, we will also do some visualization using barplots. we will print the sharewomen data from first 10 majors and last 10 majors and compare them.

# %%
recent_grads.head(10).plot.bar(x='Major',y='ShareWomen',figsize=(10,10))

# %%
recent_grads.tail(10).plot.bar(x='Major',y='ShareWomen',figsize=(10,10))

# %% [markdown]
# From the above two bar plots showing the womens share in 20 majors. The bar plot from the first plot shows 9 out of 10 majors are male dominant contrary to the other plot (last ten data) showing all 10 majors domnited by women.
